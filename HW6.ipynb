# %%
import numpy as np
import matplotlib.pyplot as plt

#initial condition 
g=9.8
v0=10
tf=2*v0/g#final time
dt=0.01#step size
y=[0,10]#0 is initial displacement 10 is initial velocity
t=0

#define dz/dt=v, dv/dt=g
def f(t, y):
    f=np.zeros(2)
    f[0]=y[1]
    f[1]=-g
    return f

#rk4 meythod    
def rk4(t, h, y):
    k1=h*f(t,y)
    k2=h*f(t+0.5*h,y+0.5*k1)
    k3=h*f(t+0.5*h,y+0.5*k2)
    k4=h*f(t+h,y+k1)
    y+=1/6*(k1+2*k2+2*k3+k4)
    return y

xp=[]
yp=[]
while(t<tf):
    y = rk4(t,dt,y)
    xp=np.append(xp,t)
    yp=np.append(yp,y[0])
    t = t+dt

plt.plot(xp,yp)
plt.show()

# %%
#Cs-137*1
#peak 1
cs_channel_1=[]
#peak 2
cs_channel_2=[367,360.45,359,358,357,374]
#whole
channel_whole_count_2=[709485,311279,210397,135167,75739,1206197]

rate_whole_cs=[]
rate_peak1_cs=[]
rate_peak2_cs=[]
for i in range(len(channel_whole_count_2)):
    rate_whole_cs.append(channel_whole_count_2[i]/el[i])
    #rate_peak1_cs.append(cs_channel_1[i]/el[i])
    rate_peak2_cs.append(cs_channel_2[i]/el[i])
    print(rate_whole_cs[i])

#plt.plot(rate_whole_cs,channel_whole_count_2)
plt.plot(rate_peak2_cs,channel_whole_count_2)
plt.xlabel("Count rate")
plt.ylabel("Channel count")
#plt.legend()
plt.show()
# Out:
# 11824.75
# 5187.983333333334
# 3506.616666666667
# 2252.7833333333333
# 1262.3166666666666
# 20103.283333333333

# %%
#Cs-137x3
#whole
channel_whole_count_3=[1936856,431058,144834]
#peak 2
cs_channel_2_tri=[390.31,395.05,356]

rate_whole_cs_tri=[]
rate_peak2_cs_tri=[]
for i in range(len(channel_whole_count_3)):
    rate_whole_cs_tri.append(channel_whole_count_3[i]/el[i])
    rate_peak2_cs_tri.append(cs_channel_2_tri[i]/el[i])
    print(rate_whole_cs_tri[i])
    
#plt.plot(rate_whole_cs_tri,channel_whole_count_3,'g')
plt.plot(rate_peak2_cs_tri,cs_channel_2_tri,'b')
plt.xlabel("Count rate")
plt.ylabel("Channel count")
#plt.legend()
plt.show()
# Out:
# 32280.933333333334
# 7184.3
# 2413.9

# %%
pip install scipy
# Out:
# ...
#
# ...

# %%
# fit a straight line to the economic data
from numpy import arange
from pandas import read_csv
from scipy.optimize import curve_fit
from matplotlib import pyplot

# define the true objective function
def objective(x, a, b):
	return a * x + b

# load the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/longley.csv'
dataframe = read_csv(url, header=None)
data = dataframe.values
# choose the input and output variables
x, y = data[:, 4], data[:, -1]
# curve fit
popt, _ = curve_fit(objective, x, y)
# summarize the parameter values
a, b = popt
print('y = %.5f * x + %.5f' % (a, b))
# plot input vs output
pyplot.scatter(x, y)
# define a sequence of inputs between the smallest and largest known inputs
x_line = arange(min(x), max(x), 1)
# calculate the output for the range
y_line = objective(x_line, a, b)
# create a line plot for the mapping function
pyplot.plot(x_line, y_line, '--', color='red')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [5], line 3
#       1 # fit a straight line to the economic data
#       2 from numpy import arange
# ----> 3 from pandas import read_csv
#       4 from scipy.optimize import curve_fit
#       5 from matplotlib import pyplot
#
# ModuleNotFoundError: No module named 'pandas'

# %%
k=[]
k.append([1,2,3])
print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 k=[]
# ----> 2 k.append[1,2,3]
#       3 print(k)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
